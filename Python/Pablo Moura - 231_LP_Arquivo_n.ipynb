# %%
arquivo = open('numeros.txt', 'w') # apagando e criando
for linha in range(1,6):
    #arquivo.write('%i\n' % linha)
    # ou assim
    arquivo.write(f'Olá {linha}\n')
arquivo.close()
print('Termino do programa')

# %% [markdown]
# ### 1. Elabore uma estrutura para representar e armazenar 10 fornecedores (código, nome, endereco). Utilize os recursos de arquivo para armazenar estes dados permanentemente. O nome do arquivo deve ser o mesmo da estrutura. Construa um menu com as seguintes opções, cada uma delas deve ter uma função e a main para chamar todas elas.
#
# Menu de opções:
# 1. Cadastrar fornecedores
# 2. Visualizar todos os dados
# 3. Sair

# %%
class TipoFornecedor:
    codigo = 0
    nome = ''
    endereco = ''

def menu():
    print('\nMenu do Sistema')
    print('1. Cadastrar fornecedores')
    print('2. Visualizar todos os dados')
    print('3. Sair')
    opcao = int(input('Qual opção deseja? '))
    return opcao

def cadastrar(forn):
    for i in range(2):
        f = TipoFornecedor()
        f.codigo = int(input('Informe o código: '))
        f.nome = input('Informe o nome: ')
        f.endereco = input('Informe o endereço: ')
        forn.append(f)
    return forn

def visualizar(forn):
    if len(forn) > 0:
        for i in range(len(forn)):
            print(f'Código: {forn[i].codigo} \tNome: {forn[i].nome} \tEndereço: {forn[i].endereco}')

def salvar_arquivo(forn):
    with open('fornecedor.txt', 'w') as arquivo:
        for f in forn:
            arquivo.write(f'{f.codigo},{f.nome},{f.endereco}\n')

def main():
    fornecedor = []
    op = menu()
    while op >= 1 and op <= 2:
        if op == 1:
            fornecedor = cadastrar(fornecedor)
            salvar_arquivo(fornecedor)
        elif op == 2:
            visualizar(fornecedor)
        op = menu()

main()
# Out:
# Menu do Sistema
# 1. Cadastrar fornecedores
# 2. Visualizar todos os dados
# 3. Sair
# Qual opção deseja? 2
#
# Menu do Sistema
# 1. Cadastrar fornecedores
# 2. Visualizar todos os dados
# 3. Sair
# Qual opção deseja? 1
# Informe o código: 1
# Informe o nome: coca
# Informe o endereço: avenida
# Informe o código: 2
# Informe o nome: pepsi
# Informe o endereço: rua 4
#
# Menu do Sistema
# 1. Cadastrar fornecedores
# 2. Visualizar todos os dados
# 3. Sair
# Qual opção deseja? 2
# Código: 1 	Nome: coca 	Endereço: avenida
# Código: 2 	Nome: pepsi 	Endereço: rua 4
#
# Menu do Sistema
# 1. Cadastrar fornecedores
# 2. Visualizar todos os dados
# 3. Sair
# Qual opção deseja? 3

# %% [markdown]
# ### 2. Elabore uma estrutura para representar e armazenar 10 produtos (código, nome, preço). Utilize os recursos de arquivo para armazenar estes dados permanentemente. O nome do arquivo deve ser o mesmo da estrutura. Construa um menu com as seguintes opções, cada uma delas deve ter uma função e a main para chamar todas elas.
#
# Menu de opções:
# 1. Cadastrar produtos
# 2. Visualizar todos os dados
# 3. Sair

# %%
# Digite seu código aqui
class TipoProduto:
    codigo = 0
    nome = ''
    preco = 0.0

def menu():
    print('\nMenu do Sistema')
    print('1. Cadastrar produtos')
    print('2. Visualizar todos os dados')
    print('3. Sair')
    opcao = int(input('Qual opção deseja? '))
    return opcao

def cadastrar(prod):
    for i in range(2):
        p = TipoFornecedor()
        p.codigo = int(input('Informe o código: '))
        p.nome = input('Informe o nome: ')
        p.preco = float(input('Informe o preço: '))
        prod.append(p)
    return prod

def visualizar(prod):
    if len(prod) > 0:
        for i in range(len(prod)):
            print(f'Código: {prod[i].codigo} \tNome: {prod[i].nome} \tEndereço: {prod[i].preco}')

def salvar_arquivo(prod):
    with open('produto.txt', 'w') as arquivo:
        for p in prod:
            arquivo.write(f'{p.codigo},{p.nome},{p.preco}\n')

def main():
    produto = []
    op = menu()
    while op >= 1 and op <= 2:
        if op == 1:
            produto = cadastrar(produto)
            salvar_arquivo(produto)
        elif op == 2:
            visualizar(produto)
        op = menu()

main()
# Out:
# Menu do Sistema
# 1. Cadastrar produtos
# 2. Visualizar todos os dados
# 3. Sair
# Qual opção deseja? 1
# Informe o código: 1
# Informe o nome: coca
# Informe o preço: 10
# Informe o código: 2
# Informe o nome: pepsi
# Informe o preço: 8
#
# Menu do Sistema
# 1. Cadastrar produtos
# 2. Visualizar todos os dados
# 3. Sair
# Qual opção deseja? 2
# Código: 1 	Nome: coca 	Endereço: 10.0
# Código: 2 	Nome: pepsi 	Endereço: 8.0
#
# Menu do Sistema
# 1. Cadastrar produtos
# 2. Visualizar todos os dados
# 3. Sair
# Qual opção deseja? 3

# %% [markdown]
# ### 3. Elabore uma estrutura para representar e armazenar 10 alunos (matricula, nome, telefone). Utilize os recursos de arquivo para armazenar estes dados permanentemente. O nome do arquivo deve ser o mesmo da estrutura. Construa um menu com as seguintes opções, cada uma delas deve ter uma função e a main para chamar todas elas.
#
# Menu de opções:
# 1. Cadastrar alunos
# 2. Visualizar todos os dados
# 3. Sair

# %%
# Digite seu código aqui
class TipoAluno:
    matricula = 0
    nome = ''
    telefone = 0

def menu():
    print('\nMenu do Sistema')
    print('1. Cadastrar aluno')
    print('2. Visualizar todos os dados')
    print('3. Sair')
    opcao = int(input('Qual opção deseja? '))
    return opcao

def cadastrar(estud):
    for i in range(2):
        a = TipoAluno()
        a.matricula = int(input('Informe o número da matricula: '))
        a.nome = input('Informe o nome: ')
        a.telefone = int(input('Informe o telefone: '))
        estud.append(a)
    return estud

def visualizar(estud):
    if len(estud) > 0:
        for i in range(len(estud)):
            print(f'matricula: {estud[i].matricula} \tNome: {estud[i].nome} \ttelefone: {estud[i].telefone}')

def salvar_arquivo(estud):
    with open('aluno.txt', 'w') as arquivo:
        for a in estud:
            arquivo.write(f'{a.matricula},{a.nome},{a.telefone}\n')

def main():
    aluno = []
    op = menu()
    while op >= 1 and op <= 2:
        if op == 1:
            aluno = cadastrar(aluno)
            salvar_arquivo(aluno)
        elif op == 2:
            visualizar(aluno)
        op = menu()

main()
# Out:
# Menu do Sistema
# 1. Cadastrar aluno
# 2. Visualizar todos os dados
# 3. Sair
# Qual opção deseja? 1
# Informe o número da matricula: 1
# Informe o nome: pablo
# Informe o telefone: 40028922
# Informe o número da matricula: 2222
# Informe o nome: lucas
# Informe o telefone: 997526520
#
# Menu do Sistema
# 1. Cadastrar aluno
# 2. Visualizar todos os dados
# 3. Sair
# Qual opção deseja? 2
# matricula: 1 	Nome: pablo 	telefone: 40028922
# matricula: 2222 	Nome: lucas 	telefone: 997526520
#
# Menu do Sistema
# 1. Cadastrar aluno
# 2. Visualizar todos os dados
# 3. Sair
# Qual opção deseja? 3

# %% [markdown]
# ### 4. Baixe o arquivo futebol.txt que esta na pasta Material do aula do Teams. Leia este arquivo e o apresente. Com os dados lidos, armazene na estrutura Futebol (posicao_jogo, altura, peso, imc), calcule o IMC (Índice de Massa Corporal), armazene na estrutura e também em outro arquivo, mas agora chamado futebol_imc.txt. Apresente este novo arquivo.
# Observação: esse exercício deve ser carregado o arquivo futebol.txt, aqui no Colab, no menu (ícone pasta) do lado esquerdo, que estará disponível no Classroom.

# %%
class TipoJogador:
    posicao_jogo = ''
    altura = 0.0
    peso = 0.0
    imc = 0.0

def leitura():
    jogadores = []
    arquivo = open('futebol.txt', 'r')
    arquivo2 = open('futebol_imc.txt', 'w')
    linhas = arquivo.readlines()
    for linha in linhas:
        posicao_jogo, altura, peso = linha.strip().split(',')
        j = TipoJogador()
        j.posicao_jogo = posicao_jogo
        j.altura = float(altura)
        j.peso = float(peso)
        j.imc = j.peso / (j.altura ** 2)
        arquivo2.write(f'{j.posicao_jogo};{j.altura};{j.peso};{j.imc:.2f}\n')

    arquivo.close()
    arquivo2.close()

def main():
    leitura()

main()
