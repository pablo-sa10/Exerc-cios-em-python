# %% [markdown]
# ### 1. Faça um programa que leia uma matriz 2x3 (2 linhas, 3 colunas). Apresente os elementos da matriz e seus respectivos índices.

# %%
# Digite aqui seu código
numeros = []
for linha in range (2):
    vet_linha = []
    for coluna in range(3):
        vet_linha.append(int(input(f'digite o valor [{linha},{coluna}]: ')))
    numeros.append(vet_linha)

print(numeros)

for linha in range(len(numeros)):
    for coluna in range(len(numeros[0])):
        print(numeros[linha][coluna], end = '    ')
    print()

for linha in range(len(numeros)):
    for coluna in range(len(numeros[0])):
        print(f'Elemento: {numeros[linha][coluna]}\tíndice de linha: {linha}\tíndice da coluna: {coluna}')
# Out:
# digite o valor [0,0]: 1
# digite o valor [0,1]: 2
# digite o valor [0,2]: 3
# digite o valor [1,0]: 4
# digite o valor [1,1]: 5
# digite o valor [1,2]: 6
# [[1, 2, 3], [4, 5, 6]]
# 1    2    3
# 4    5    6
# Elemento: 1	índice de linha: 0	índice da coluna: 0
# Elemento: 2	índice de linha: 0	índice da coluna: 1
# Elemento: 3	índice de linha: 0	índice da coluna: 2
# Elemento: 4	índice de linha: 1	índice da coluna: 0
# Elemento: 5	índice de linha: 1	índice da coluna: 1
# Elemento: 6	índice de linha: 1	índice da coluna: 2

# %% [markdown]
# ### 2. Faça um programa que carregue uma matriz 2 x 2, que representa o salário de 4 funcionários, calcule e mostre a soma total de todos os elementos que será o montante pago pela empresa a esses funcionários.

# %%
# Digite aqui seu código
salario = []
soma = 0
for linha in range(2):
    vet_linha = []
    for coluna in range(2):
        vet_linha.append(float(input(f'Digite o salario[{linha}][{coluna}] R$: ')))
        soma = soma + vet_linha[coluna]
    salario.append(vet_linha)

print(f'\na soma dos salarios que a empresa pagará será de R$: {soma}')
# Out:
# Digite o salario[0][0] R$: 100
# Digite o salario[0][1] R$: 200
# Digite o salario[1][0] R$: 300
# Digite o salario[1][1] R$: 400
#
# a soma dos salarios que a empresa pagará será de R$: 1000.0

# %% [markdown]
# ### 3. Faça um programa que carregue uma matriz 3 x 2, que representa preços de produtos, crie OUTRA matriz que armazene todos os preços com 7% de aumento.

# %%
# Digite aqui seu código
preco = []
aumento = []
for linha in range(3):
    vet_linha = []
    for coluna in range(2):
        vet_linha.append(float(input(f'Digite o preço[{linha}][{coluna}] R$: ')))
    preco.append(vet_linha)    

print('\nApresentação da matriz aumento........')
for linha in range(len(preco)):
    vet_linha = []
    for coluna in range(len(preco[0])):
        vet_linha.append(preco[linha][coluna]*7/100+preco[linha][coluna])
        print(vet_linha[coluna],end='\t')
    aumento.append(vet_linha)
    print()
# Out:
# Digite o preço[0][0] R$: 2000
# Digite o preço[0][1] R$: 3000
# Digite o preço[1][0] R$: 125
# Digite o preço[1][1] R$: 256
# Digite o preço[2][0] R$: 694
# Digite o preço[2][1] R$: 7200
#
# Apresentação da matriz aumento........
# 2140.0	3210.0
# 133.75	273.92
# 742.58	7704.0

# %% [markdown]
# ### 4. Faça um programa para armazenar em uma matriz 5x2 preços. Encontre e apresente os ÍNDICES dos valores menores que 23 reais.

# %%
# if matriz[lin][col] < 23:
#     print(lin)
#     print(col)

preco = []
for linha in range(5):
    vet_linha = []
    for coluna in range(2):
        vet_linha.append(float(input(f'Digite o preço[{linha}][{coluna}] R$: ')))
    preco.append(vet_linha)

for linha in range(len(preco)):
    for coluna in range(len(preco[0])):
        if preco[linha][coluna] < 23:
          print(f'linha:{linha} coluna:{coluna}')
# Out:
# Digite o preço[0][0] R$: 200
# Digite o preço[0][1] R$: 100
# Digite o preço[1][0] R$: 22
# Digite o preço[1][1] R$: 100
# Digite o preço[2][0] R$: 22
# Digite o preço[2][1] R$: 300
# Digite o preço[3][0] R$: 100
# Digite o preço[3][1] R$: 22
# Digite o preço[4][0] R$: 300
# Digite o preço[4][1] R$: 300
# linha:1 coluna:0
# linha:2 coluna:0
# linha:3 coluna:1

# %% [markdown]
# ### 5. Faça um programa que leia números inteiros m e n e os elementos de uma matriz A de números inteiros de dimensão m x n e conte o número de elementos que são iguais a zero.

# %%
# Digite aqui seu código
matriz = []
m = int(input('informe a qauntidade de linhas da matriz: '))
n = int(input('informe a qauntidade de colunas da matriz: '))
i = 0
for linha in range(m):
    vetor = []
    for coluna in range(n):
        vetor.append(int(input(f'\nDigite um numero[{linha}][{coluna}]: ')))
    matriz.append(vetor)
    if vetor [coluna] == 0:
        i += 1
print(matriz)
print(f'\na quantidade de elementos iguais a zero é: {i}')
# Out:
# informe a qauntidade de linhas da matriz: 4
# informe a qauntidade de colunas da matriz: 4
#
# Digite um numero[0][0]: 5
#
# Digite um numero[0][1]: 6
#
# Digite um numero[0][2]: 0
#
# Digite um numero[0][3]: 7
#
# Digite um numero[1][0]: 8
#
# Digite um numero[1][1]: 9
#
# Digite um numero[1][2]: 10
#
# Digite um numero[1][3]: 22
#
# Digite um numero[2][0]: 74
#
# Digite um numero[2][1]: 5
#
# Digite um numero[2][2]: 6
#
# Digite um numero[2][3]: 69
#
# Digite um numero[3][0]: 0
#
# Digite um numero[3][1]: 78
#
# Digite um numero[3][2]: 1200
#
# Digite um numero[3][3]: -258963258
# [[5, 6, 0, 7], [8, 9, 10, 22], [74, 5, 6, 69], [0, 78, 1200, -258963258]]
#
# a quantidade de elementos iguais a zero é: 0

# %% [markdown]
# ### 6. Faça um programa que carregue: *um vetor com oito posições com os nomes das lojas; * um outro vetor com quatro posições com os nomes dos produtos; * uma matriz (8 x 4) com os preços de todos os produtos em cada loja. O programa deve mostrar todas as relações (nome da loja - nome do produto e preço), nas quais o preço não ultrapasse R$ 120,00.

# %%
# for lin até 8    lojas
#    for col até 4    produtos
loja = []
produto = []
matriz = []
for linha in range(4):
    loja.append(input('informe o nome da loja: '))
print(f'\nLojas: {loja}')
for coluna in range(2):
    produto.append(input(f'digite o nome do produto: '))
print(f'\nProdutos: {produto}')
for linha in range(4):
    preco = []
    for coluna in range(2):
        preco.append(float(input(f'digite o preço do produto [{linha}][{coluna}] R$: ')))
    matriz.append(preco)
for linha in range(len(matriz)):
    for coluna in range(len(matriz[0])):
        if matriz [linha][coluna] <= 120:
            print(f'na loja {loja[linha]}, o produto {produto[coluna]} custa, {matriz [linha] [coluna]}')
# Out:
# informe o nome da loja: a
# informe o nome da loja: b
# informe o nome da loja: c
# informe o nome da loja: d
#
# Lojas: ['a', 'b', 'c', 'd']
# digite o nome do produto: a
# digite o nome do produto: b
#
# Produtos: ['a', 'b']
# digite o preço do produto [0][0] R$: 150
# digite o preço do produto [0][1] R$: 893
# digite o preço do produto [1][0] R$: 100
# digite o preço do produto [1][1] R$: 1000
# digite o preço do produto [2][0] R$: 785
# digite o preço do produto [2][1] R$: 152
# digite o preço do produto [3][0] R$: 455
# digite o preço do produto [3][1] R$: 499
# na loja b, o produto a custa, 100.0

# %%
[{linha}]
