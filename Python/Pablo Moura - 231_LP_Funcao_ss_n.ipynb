# %%
nome = 'bob'
idade = 23
grana = 31.4765
print("%s tem %i anos e R$%f no bolso. " % (nome, idade, grana) )
print("%10s tem %5i anos e R$%15.2f no bolso. " % (nome, idade, grana) )
print("%10s tem %3i anos e R$%15.2f no bolso. " % (nome, idade, grana) )

print('{0:<40}.......', format(nome))
print('(0:^40).......', format(nome))
# Out:
# bob tem 23 anos e R$31.476500 no bolso.
#        bob tem    23 anos e R$          31.48 no bolso.
#        bob tem  23 anos e R$          31.48 no bolso.
# {0:<40}....... bob
# (0:^40)....... bob

# %% [markdown]
# ### 1.0 (Função sem retorno sem parâmetro) Faça um programa contendo uma função/método que leia um número e o multiplique por 2. Apresente o resultado. EXEMPLO.

# %%
#definição da função
def multiplicar():
    numero = 
    print('O resultado é', numero * 2)

def main():
    #chamada da função multiplicar
    multiplicar()

#chamada da função main()
main()
# Out:
# Digite o número: 6
# O resultado é 12

# %%
def multiplicador ():#definição da função
    numero = int(input('digite um numero: '))
    print('resultado da multiplicação', numero * 2)

def main ():#chamada da função multiplicar
    multiplicador()

main()#chamada da função main()

# %%
def multiplicar():
    numero = int(input('digite um numero: '))
    print('resultado da muletiplicação:', numero * 2)
def main():
    print('iniciando')
    multiplicar()
    print('sair')

main()
# Out:
# iniciando
# digite um numero: 2
# resultado da muletiplicação: 4
# sair

# %% [markdown]
# ### 1.1 (Função sem retorno sem parâmetro) Faça um programa contendo uma função/método que apresente o valor 1 se o número digitado for positivo e 0 se for negativo.

# %%
def numero():
    valor = int(input('Digite o número: '))
    if valor > 0:
        print(1)
    else:
        print(0)

def main():
    numero()

main()
# Out:
# Digite o número: -2
# 0

# %% [markdown]
# ### 2. (Função sem retorno sem parâmetro) Faça uma função/método que leia dois valores positivos e apresente a soma dos N números existentes entre eles (inclusive).
#     Exemplo:
#         a = 2
#         b = 8
#         2 + 3 + 4 + 5 + 6 + 7 + 8
#         soma = 35

# %%
# Digite seu código aqui.
def resultado():
    soma = 0
    for i in range(2,11):
        soma = soma + i
        print(soma)

def main():
    resultado()

main()
# Out:
# 2
# 5
# 9
# 14
# 20
# 27
# 35
# 44
# 54

# %% [markdown]
# ### 3. (Função sem retorno sem parâmetro) Faça uma função/método que receba três números inteiros *a*, *b*, *c* que sejam divisíveis por ***a***. Os valores *b* e *c* representam o intervalo da estrutura de repetição. Apresente a quantidade e os números divisíveis. Não pode usar vetor e função pronta da linguagem Python.
#     Exemplo:
#         a = 5
#         b = 1
#         c = 10
#         1 % a
#         2 % a
#         3 % a
#         4 % a
#         5 % a este valor é divisível
#         6 % a
#         7
#         8
#         9
#         10 % a este valor é divisível
#         qtde = 2

# %%
# Digite seu código aqui.
def valor():
    a = int(input('escreva primeiro numero: '))
    b = int(input('escreva o segundo numero: '))
    c = int(input('escreva terceiro numero: '))
    numero = 0
    for i in range (b,c+1):
        numero = i % a
        if numero == 0:
            print(i, 'é divisível')
        else:
            print(i, 'não é divisível')

def main():
    valor()

main()
# Out:
# escreva primeiro numero: 2
# escreva o segundo numero: 1
# escreva terceiro numero: 10
# 1 não é divisível
# 2 é divisível
# 3 não é divisível
# 4 é divisível
# 5 não é divisível
# 6 é divisível
# 7 não é divisível
# 8 é divisível
# 9 não é divisível
# 10 é divisível

# %% [markdown]
# ### 4. (Função sem retorno sem parâmetro) Faça uma função/método que leia um único valor representado em segundos, converta-o e apresente o resultado em horas, minutos e segundos.
#     h = segundos / 3600
#     r = resto(segundos / 3600)
#     m = r / 60
#     s = resto(r / 60)
#     Observação 1: resto de uma divisão em Python %.
#     Observação 2: a hora, o minuto e o segundo devem ser apresentados como números inteiros.

# %%
# Digite seu código aqui.
def tempo():
    segundos = int(input('digite um valor representado em segundos: '))
    h = segundos / 3600
    r = segundos % 3600
    m = r / 60
    s = r % 60
    print(f'Horários: {h:.0f}h {m:.0f}m {s:.0f}s')

def main():
    tempo()

main()
# Out:
# digite um valor representado em segundos: 7876543
# Horários: 2188h 56m 43s

# %% [markdown]
# ### 5. (Função sem retorno sem parâmetro) Faça uma função/método que receba o preço antigo e atual de um produto, determine o percentual de acréscimo entre esses valores e apresente-o.
#     r = (100 * preco_novo - 100 * preco_antigo) / preco_antigo

# %%
def valor():
    preco_antigo = float(input('digite o valor antigo: '))
    preco_novo = float(input('digite o valor atual: '))
    acrescimo = (100 * preco_novo - 100 * preco_antigo) / preco_antigo
    print('os acrescimos do preço do produto foi de:', acrescimo,'%')

def main():
    valor()

main()
# Out:
# digite o valor antigo: 100
# digite o valor atual: 150
# os acrescimos do preço do produto foi de: 50.0 %

# %% [markdown]
# ### 6. (Função sem retorno sem parâmetro) Faça uma função/método que leia um valor inteiro entre 1 e 9 e mostre a seguinte tabela de **multiplicação**
# Neste exemplo foi escolhido o número 9.
#
#     1
#     2     4
#     3     6     9
#     4     8    12    16
#     5    10    15    20    25
#     6    12    18    24    30    36
#     7    14    21    28    35    42    49
#     8    16    24    32    40    48    56    64
#     9    18    27    36    45    54    63    72    81
#     for i = 1 até n
#        for j = 1 até i
#
#     Observação: configure o print para não pular linha, use o parâmetro end.

# %%
# Digite seu código aqui. 
# Para ter a mesma forma de apresentação use assim o print(r, end = '\t')
def tabuada():
    n = int(input('digite um numero de 1 ao 9: '))
    for i in range(1,n+1):
        for j in range(1,i+1):
            r = i * j
            print(r, end = '\t')
        print()
tabuada()
# Out:
# digite um numero de 1 ao 9: 5
# 1
# 2	4
# 3	6	9
# 4	8	12	16
# 5	10	15	20	25

# %% [markdown]
# ### 7. (Função sem retorno sem parâmetro) Faça uma função/método que leia três notas de um aluno e uma letra, se a letra for igual a *A*, deverá calcular a média aritimética das notas dos alunos, se for *P*, deverá calcular a média ponderada, com pesos 5, 3 e 2. A média deve ser mostrada ao final.
# N1, N2 e N3 são notas.
#
# P1, P2 e P3 são pesos.
#
# Média ponderada = (N1 * P1 + N2 * P2 + N3 * P3 ) / (P1 + P2 + P3)

# %%
# Digite seu código aqui.
def notas():
    p1 = 5
    p2 = 3
    p3 = 2
    n1 = int(input('digite a primeira nota do aluno: '))
    n2 = int(input('digite a primeira nota do aluno: '))
    n3 = int(input('digite a primeira nota do aluno: '))
    letra = (input('digite P para média ponderada ou A para médoa aritimética: '))
    if letra == 'P' or letra == 'p':
        media = (n1 * p1 + n2 * p2 + n3 * p3 ) / (p1 + p2 + p3)
        print(f'a media é: {media}')
    elif letra == 'A' or letra == 'a':
        media = (n1 + n2 + n3) / 3
        print(f'a media é: {media}')

def main():
    notas()

main()
# Out:
# digite a primeira nota do aluno: 6
# digite a primeira nota do aluno: 9
# digite a primeira nota do aluno: 10
# digite P para média ponderada ou A para médoa aritimética: a
# a media é: 8.333333333333334

# %% [markdown]
# ### 8. (Função sem retorno sem parâmetro) Faça uma função/método que leia uma hora de início e de término de um jogo, ambas divididas em dois valores distintos: hora e minuto. Deverá ser apresentado a duração expressa em minutos, considerando que o tempo máximo de duração de um jogo é de 24 horas e que ele pode começar em um dia e terminar no outro.
#     se m_f < m_i
#         m_f = m_f + 60
#         h_f = h_f - 1
#     se h_f < h_i
#         h_f = h_f + 24
#     tot_m = m_f - m_i
#     tot_h = h_f - h_i
#     total = tot_h * 60 + tot_m

# %%
# Digite seu código aqui.
def definir():
    h_i = int(input('digite a hora que o jogo começou: '))
    m_i = int(input('digite os minutos do ínicio do jogo: '))
    h_f = int(input('digite a hora do término do jogo: '))
    m_f = int(input('digite os minutos do término do jogo: '))

    if m_f < m_i:
        m_f = m_f + 60
        h_f = h_f - 1
    if h_f < h_i:
        h_f = h_f + 24
    tot_m = m_f - m_i
    tot_h = h_f - h_i
    total = tot_h * 60 + tot_m 
    print('a quantidade de minutos totais entre o ínicio e o fim do jogo é de:', total)

definir()
# Out:
# digite a hora que o jogo começou: 21
# digite os minutos do ínicio do jogo: 54
# digite a hora do término do jogo: 4
# digite os minutos do término do jogo: 10
# a quantidade de minutos totais entre o ínicio e o fim do jogo é de: 376

# %% [markdown]
# ### 9. (Função sem retorno sem parâmetro) Faça uma função/método que leia cinco valores inteiros, determine e mostre o maior e o menor deles. Não pode usar vetor e função pronta da linguagem Python.

# %%
# Digite seu código aqui.
def valor():
    for i in range(5):
        numero = int(input('digite um numero inteiro: '))
        if i == 0:
            maior = numero
            menor = numero
        if numero > maior:
            maior = numero
        if numero < menor:
            menor = numero

    print('O maior valor é:', maior)
    print('O menor valor é:', menor)

def main():
    valor()

main()
# Out:
# digite um numero inteiro: 1
# digite um numero inteiro: 2
# digite um numero inteiro: 3
# digite um numero inteiro: 4
# digite um numero inteiro: 5
# O maior valor é: 5
# O menor valor é: 1

# %% [markdown]
# ### 10. (Função sem retorno sem parâmetro) Faça uma função/método que leia um valor inteiro e positivo N e mostre o valor de S, obtido pelo seguinte cálculo:
# ###S = 1  +  1/1!  +  1/2!  +  1/3!  + ... +  1/N!
#
# Observvação: Não pode usar vetor e função pronta da linguagem Python.

# %%
# Digite seu código aqui.
# S = 1
# S = 1 + 1 + 1/2! + 1/3 + 1/4!
# S = 1 + 1 + 0.5 + 0.16 + 0.041
# S = 2.66 + 0.041
# 3! = 3 * 2 * 1 = 6
# 4! = 1 * 2 * 3 * 4 = 24    1/4!   1/24  = 0.041

# N = int(input('Informe o valor de N termos: '))
def calcular():
    n = int(input("Digite um número inteiro e positivo: "))
    fatorial = 1
    s = 1
    for i in range(1, n + 1):
        fatorial *= i
        s += 1 / fatorial
    print("O valor de S é:", s)

def main():
    calcular()

main()
# Out:
# Digite um número inteiro e positivo: 2
# O valor de S é: 2.5
