# %% [markdown]
# ### **EXERCÍCIOS DE ESTRUTURA DE REPETIÇÃO SEM CONTADOR**

# %% [markdown]
# ###1. Construir um algoritmo para calcular e apresentar o total de salários pagos de funcionários, mas não é informado a quantidade de pessoas, então use como critério de parada (condição da estrutura de repetição, digitar zero no salário para sair.

# %%
salario = float(input('...Para encerrar digite zero. Informe o salário R$ '))
total = 0
while salario > 0:
    total = total + salario
    salario = float(input('Para encerrar digite zero. Informe o salário R$ '))
print(f'Total de salários pagos R$ {total:.2f}')
# Out:
# ...Para encerrar digite zero. Informe o salário R$ 1000
# Para encerrar digite zero. Informe o salário R$ 5000
# Para encerrar digite zero. Informe o salário R$ 6000
# Para encerrar digite zero. Informe o salário R$ -10
# Total de salários pagos R$ 12000.00

# %%
# GAMBIARRA
salario = 1 # estou forçando a entrada na estrutura de repetição
total = 0
while salario > 0: 
    salario = float(input('Informe o salário... '))
    if salario > 0: # O que adiantou forçar a entrada na repetição???
        total = total + salario    
print('O total de salários pagos é',total)
# Out:
# Informe o salário... 1000
# Informe o salário... 5000
# Informe o salário... 6000
# Informe o salário... -10
# O total de salários pagos é 12000.0

# %% [markdown]
# ###2. Faça um programa que receba a altura de 5 pessoas. Encontre e apresente a altura da pessoa mais alta e da mais baixa e seus respectivos nomes.

# %%
for pessoas in range(5):
    altura = float(input('Informe a altura: '))
    nome = input('Informe o nome: ')
    # dica de implementação, inicializar as variáveis de menor e maior
    # valor dentro do laço de repetição, quando você souber, quantas
    # vezes repete
    if pessoas == 0:
        alto = altura
        nomea = nome
        baixo = altura
        nomeb = nome
    if altura >= alto:
        alto = altura
        nomea = nome
    elif altura <= baixo:
        baixo = altura
        nomeb = nome
print(nomea,'é mais alto, com',alto,'metros')
print(nomeb,'é mais baixo, com',baixo,'metros')
# Out:
# Informe a altura: 1.78
# Informe o nome: Lucas
# Informe a altura: 1.8
# Informe o nome: Andres
# Informe a altura: 1.75
# Informe o nome: Felipe
# Informe a altura: 1.8
# Informe o nome: Edivaldo
# Informe a altura: 1.65
# Informe o nome: Patricia
# Edivaldo é mais alto, com 1.8 metros
# Patricia é mais baixo, com 1.65 metros

# %% [markdown]
# ###3. Faça um programa que receba a altura de várias pessoas. Encontre e apresente a altura da pessoa mais alta e da mais baixa e seus respectivos nomes. Para encerrar a entrada de dados, zero na altura, mas esta não poderá ser considerada como resposta da altura da pessoa mais baixa.

# %%
altura = float(input('Informe a altura: '))
nome = input('Informe o nome: ')
alto = altura
nomea = nome
baixo = altura
nomeb = nome
while altura >0:
    if altura >= alto:
        alto = altura
        nomea = nome
    elif altura <= baixo:
        baixo = altura
        nomeb = nome
    altura = float(input('Informe a altura: '))
    nome = input('Informe o nome: ')
print(nomea,'é mais alto, com',alto,'metros')
print(nomeb,'é mais baixo, com',baixo,'metros')
# Out:
# Informe a altura: 180
# Informe o nome: paablo
# Informe a altura: 160
# Informe o nome: grazi
# Informe a altura: 0
# Informe o nome: nulo
# paablo é mais alto, com 180.0 metros
# grazi é mais baixo, com 160.0 metros

# %% [markdown]
# ###4. Faça um programa que receba a idade e a altura de várias pessoas. Calcule e exiba a média das alturas das pessoas com mais de 20 anos. Para encerrar a entrada de dados, digite uma idade negativa ou igual a zero.

# %%
idade = int(input('insira a idade da pessoa '))
altura_total = 0
pessoas = 0
while idade > 0:
    altura = float(input('receba a altura da pessoa '))
    if idade > 20:
        altura_total = altura_total + altura
        pessoas += 1
    idade = int(input('digite zero para encerrar... insira a idade da pessoa '))
media = altura_total / pessoas
print(f'a media das alturas da pessoas com mais de 20 anos é:{media:.2f}')
# Out:
# insira a idade da pessoa 22
# receba a altura da pessoa 180
# digite zero para encerrar... insira a idade da pessoa 24
# receba a altura da pessoa 170
# digite zero para encerrar... insira a idade da pessoa 19
# receba a altura da pessoa 175
# digite zero para encerrar... insira a idade da pessoa 30
# receba a altura da pessoa 200
# digite zero para encerrar... insira a idade da pessoa 0
# a media das alturas da pessoas com mais de 20 anos é:183.33

# %% [markdown]
# ###5. Construir um algoritmo para calcular e apresentar a idade atual de algumas pessoas em relação ao ano atual, mas não é informado a quantidade de pessoas, então use como critério de parada (condição da estrutura de repetição, digitar zero no ano de nascimento para sair.

# %%
nascimento = int(input('para encerrar digite zero.... insira o ano de nascimento da pessoa '))
idade = 2022 - nascimento
print('a idade da pessoa é:',idade)
while nascimento > 0:
    nascimento = int(input('para encerrar digite zero.... insira o ano de nascimento da pessoa '))
    idade = 2022 - nascimento
    print('a idade da pessoa é:',idade)
# Out:
# para encerrar digite zero.... insira o ano de nascimento da pessoa 2002
# a idade da pessoa é: 20
# para encerrar digite zero.... insira o ano de nascimento da pessoa 2003
# a idade da pessoa é: 19
# para encerrar digite zero.... insira o ano de nascimento da pessoa 1989
# a idade da pessoa é: 33
# para encerrar digite zero.... insira o ano de nascimento da pessoa 2021
# a idade da pessoa é: 1
# para encerrar digite zero.... insira o ano de nascimento da pessoa 0
# a idade da pessoa é: 2022

# %% [markdown]
# ###6. Faça um programa que receba um conjunto de valores inteiros, calcule e exiba o maior e o menor valor do conjunto.
#
#
# *   Para encerrar a entrada de dados, deve ser digitado o valor zero;
# *   Para valores negativos, deve ser enviada uma mensagem;
# *   Esses valores (zero e negativos) não entrarão na lógica de encontrar o maior e o menor valor.

# %%
valor = int(input('digite um numero inteiro: '))
maior = valor
menor = valor
while valor > 0:
    if valor >= maior:
        maior = valor
    elif valor <= menor:
        menor = valor
    valor = int(input('digite um numero inteiro maior que zero: '))
print('o valor', maior,'é maior, e', menor, 'é o valor menor')
# Out:
# digite um numero inteiro: 1
# digite um numero inteiro maior que zero: 2
# digite um numero inteiro maior que zero: 3
# digite um numero inteiro maior que zero: 0
# o valor 3 é maior, e 1 é o valor menor

# %% [markdown]
# ###7. No final do ano muitas pessoas compram presentes. Faça um programa que registre alguns dados das pessoas, usando como critério de parada a letra ‘n’, para a pergunta “Deseja cadastrar outro (‘s’/’n’)?”, para identificar o perfil dos compradores numa loja de roupas e apresente como resultado a:
# a)   Quantidade de mulheres e de homens;
#
# b)   Quantidade de mulheres e de homens abaixo e acima de 18 anos.

# %%
# Digite seu código aqui
# item a) 2 contadores
# item b) 4 contadores 
cadastro = input('Deseja cadastrar outro (‘s’/’n’)?' )
mulher = 0
mulher_maior = 0
mulher_menor = 0
homem = 0
homem_maior = 0
homem_menor = 0
while cadastro == 's' or cadastro == 'S':
    gen = input('informe "M" para masculino, ou "F" para feminino' )
    idade = int(input('insira a idade da pessoa '))
    if gen == 'f' or gen == 'F':
        mulher += 1
        if idade >= 18:
            mulher_maior += 1
        else:
            mulher_menor += 1
    elif gen == 'm' or gen == 'M':
        homem += 1
        if idade >= 18:
            homem_maior += 1
        else:
            homem_menor += 1
    else:
        print('genero invalido')
    cadastro = input('Deseja cadastrar outro (‘s’/’n’)?' )

print('há',mulher,'mulher(es).',mulher_maior,'é maior de idade e,',mulher_menor,'menor de idade' )
print('há',homem,'Homem(ens).',homem_maior,'é maior de idade e,',homem_menor,'menor de idade' )
# Out:
# Deseja cadastrar outro (‘s’/’n’)?S
# informe "M" para masculino, ou "F" para femininoF
# insira a idade da pessoa 19
# Deseja cadastrar outro (‘s’/’n’)?s
# informe "M" para masculino, ou "F" para femininom
# insira a idade da pessoa 18
# Deseja cadastrar outro (‘s’/’n’)?s
# informe "M" para masculino, ou "F" para femininom
# insira a idade da pessoa 15
# Deseja cadastrar outro (‘s’/’n’)?n
# há 1 mulher(es). 1 é maior de idade e, 0 menor de idade
# há 2 Homem(ens). 1 é maior de idade e, 1 menor de idade
