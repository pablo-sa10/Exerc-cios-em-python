# %% [markdown]
# # Exercícios para construir programas com ENTRADA, PROCESSAMENTO e SAÍDA

# %% [markdown]
# ### 1. Faça um programa que leia um número, multiplique ele por 2 e apresente o resultado.
#       LEIA numero
#       resultado = numero * 2
#       ESCREVA resultado

# %%
# 1º passo - identificar a(s) entrada(s) - variável número
numero = int(input('Informe um valor: '))
# 2º passo - identificar o processamento/cálculo
resultado = numero * 2
# 3º passo - apresentar a(s) variáveis que foram calculadas
print('O resultado é',resultado)
# Out:
# Informe um valor: 10
# O resultado é 20

# %% [markdown]
# ### 2. Faça um programa que:
# * receba três números inteiros
# * calcule e mostre a soma desses números.

# %%
# 1° passo - entrada de dados/valores
numero1 = int(input('cadastre o primeiro numero: '))
numero2 = int(input('cadastre o segundo numero: '))
numero3 = int(input('cadastre o terceiro numero: '))
# 2º passo - processamento/cálculo
resultado = numero1 + numero2 + numero3
# 3° passo - saída/apresentação de resultado
print('a soma dos numeros é', resultado)
# Out:
# a soma dos numeros é 15

# %% [markdown]
# ### 3. Faça um programa que receba três notas, calcule e mostre a média aritmética.

# %%
# 1º passo - entrada de dados
nota1 = float(input('cadastre a primeira nota: '))
nota2 = int(input('cadastre a segunda nota: '))
nota3 = float(input('cadastre o terceiro numero '))
# 2º passo - cálculo/processamento
resultado = (nota1 + nota2 + nota3) / 3
#3° passo - saída
print('a media dos alunos é', resultado)
# Out:
# cadastre a primeira nota: 6.5
# cadastre a segunda nota: 8
# cadastre o terceiro numero 9.5
# a media dos alunos é 8.0

# %% [markdown]
# ### 4. Faça um programa que:
# * receba o salário de um funcionário
# * calcule e mostre o novo salário, sabendo-se que este sofreu um aumento de 25%.
#
#       LEIA salario
#       novoSalario = salario + (salario * 25 / 100)
#       ESCREVA novoSalario

# %%
# Digite seu código aqui.
salario = float(input('cadastre o salario: '))
novo_salario = salario + (salario * 25 / 100)
print('o novo salario é', novo_salario)
# Out:
# cadastre o salario: 1216.50
# o novo salario é 1520.625

# %% [markdown]
# ### 5. Faça um programa que receba o salário de um funcionário e o percentual de aumento, calcule e mostre o valor do aumento e o novo salário.

# %%
salario = int(input('insira o salario '))
aumento = float(input('insira a porcentagem '))
conta1 = salario * (aumento / 100)
novo_salario = conta1 + salario
print('o novo salario é', novo_salario)
# Out:
# insira o salario 1000
# insira a porcentagem 7.3
# o novo salario é 1073.0

# %% [markdown]
# ### 6. Faça um programa que receba o salário base de um funcionário, calcule e mostre o salário a receber, sabendo-se que o funcionário tem gratificação de 5% sobre o salário base e **paga imposto** de 7% também sobre o salário base.

# %%
salario = int(input('cadastre um salario '))
gratificacao = salario * 5 / 100
imposto = salario * 7 / 100
salario_a_receber = salario + gratificacao - imposto
print('o valor da gratificacao é', gratificacao)
print('o valor do imposto é', imposto)
print('o salario a receber é', salario_a_receber)
# Out:
# cadastre um salario 1000
# o valor da gratificacao é 50.0
# o valor do imposto é 70.0
# o salario a receber é 980.0

# %% [markdown]
# ### 7. Faça um programa que receba o salário base de um funcionário, calcule e mostre seu salário a receber, sabendo-se que o funcionário tem gratificação de 50,00 sobre o salário base e **paga** imposto que deve ser lido e é aplicado sobre o salário base.
#
#     LEIA salario, perImposto
#     imposto = salario * perImposto / 100
#     salario_a_receber = salario + 50 - imposto
#     ESCREVA salario_a_receber

# %%
salario_base = int(input('insira o salario base '))
imposto =  salario_base * (10 / 100)
salario_a_receber = salario_base + 50 - imposto
print('o salario a receber é', salario_a_receber)
# Out:
# insira o salario base 1000
# o salario a receber é 950.0

# %% [markdown]
# ### 8. Faça um programa que receba o valor de um depósito e o valor da taxa de juros, calcule e mostre o valor do rendimento e o valor total depois do rendimento de um mês.
#     rendimento = deposito * taxa / 100
#     total = deposito + rendimento

# %%
deposito = int(input('insira o deposito '))
taxa = int(input('insira a taxa '))
rendimento = deposito * taxa / 100
total = deposito + rendimento
print('o rendimento total vai ser', total)
# Out:
# insira o deposito 4000
# insira a taxa 100
# o rendimento total vai ser 8000.0

# %% [markdown]
# ### 9. Faça um programa que calcule e mostre a área de um triângulo. Sabe-se que: Área = (base * altura) / 2.

# %%
base = int(input('insira a base '))
altura = float(input('insira a altura '))
area = (base * altura) / 2
print('a area do triangulo é', area)
# Out:
# insira a base 4
# insira a altura 5
# a area do triangulo é 10.0

# %% [markdown]
# ### 10. Faça um programa que calcule e mostre a área de um círculo. Sabe-se que:
#     area = pi * raio² ou
#     area = 3.1415 * raio²

# %%
raio = int(input('insira o raio '))
area = 3.1415 * raio**2
print(f'a medida do circulo é {area:.2f}')
# Out:
# insira o raio 5
# a medida do circulo é 78.54

# %% [markdown]
# ### 11. Faça um programa que receba um número, calcule e mostre:
# * O número digitado ao quadrado
# * O número digitado ao cubo
# * A raiz do número digitado
# * A raiz cúbica do número digitado
#
#       LEIA numero
#       quadrado = numero ** 2
#       cubo = numero ** 3
#       raiz_quadrada = numero ** (½) (meio, ou 0.5)
#       raiz_cubica = numero ** (⅓) (um terço, ou 0.33)
#       ESCREVA quadrado, cubo, raiz_quadrada, raiz_cubica
#
#
#       raiz_quadrada = numero ** (1/2) ou
#       raiz_quadrada = numero ** 0.5

# %%
numero1 = int(input('insira o numero1 '))
numero2 = int(input('insira o numero2 '))
numero3 = int(input('insira o numero3 '))
numero4 = int(input('insira o numero4 '))
quadrado = numero1 **2
cubo = numero2 **3
raiz_quadrada = numero3 **0.5
raiz_cubica = numero4 **(1/3)
print('o numero digitado ao quadrado é', quadrado)
print('o numero digitado ao cubo é', cubo)
print('a raiz do numero digitado é', raiz_quadrada)
print('a raiz cubica do numero digitado é', raiz_cubica)
# Out:
# insira o numero1 4
# insira o numero2 4
# insira o numero3 4
# insira o numero4 4
# o numero digitado ao quadrado é 16
# o numero digitado ao cubo é 64
# a raiz do numero digitado é 2.0
# a raiz cubica do numero digitado é 1.5874010519681994

# %% [markdown]
# ### 12. Faça um programa que receba dois números, calcule e mostre um elevado ao outro. Use os caracteres **

# %%
numero1 = int(input('insira o numero1 '))
numero2 = int(input('insira o numero2 '))
calculo = numero1 ** numero2
print('o resultado é', calculo)
# Out:
# insira o numero1 24
# insira o numero2 7
# o resultado é 4586471424

# %% [markdown]
# ### 13. Sabe-se que:
#
# * pé = 12 polegadas
# * 1 jarda = 3 pés
# * 1 milha = 1760 jarda
#
# Faça um programa que receba uma medida em pés, faça as conversões a seguir e mostre os resultados.
#
# * Polegadas;
# * Jardas;
# * Milhas.
#
#       LEIA pes
#       polegadas = pes * 12
#       jardas = pes / 3
#       milhas = jardas / 1760
#       ESCREVA polegadas, jardas, milhas

# %%
pes = int(input('insira o valor '))
polegadas = pes * 12
jardas = pes / 3
milhas = jardas / 1760
print('a convercao é', polegadas)
print('a convercao é', jardas)
print('a convercao é', milhas)
# Out:
# insira o valor 5000
# a convercao é 60000
# a convercao é 1666.6666666666667
# a convercao é 0.946969696969697

# %% [markdown]
# ### 14. Faça um programa que receba o ano de nascimento de uma pessoa e o ano atual, calcule e mostre:
# * a idade atual da pessoa;
# * quantos anos ela terá em 2050.

# %%
ano_de_nascimento = int(input('insira o ano '))
ano_atual = int(input('insira o ano '))
idade = ano_atual - ano_de_nascimento
idade_no_futuro = 2050 - ano_atual + idade
print('a idade da pessoa é', idade)
print('a idade da pessoa em 2050 sera', idade_no_futuro)
# Out:
# insira o ano 1990
# insira o ano 2022
# a idade da pessoa é 32
# a idade da pessoa em 2050 sera 60

# %% [markdown]
# #### 15. O custo ao consumidor de um carro novo é a soma do preço de fábrica com o percentual de lucro do distribuidor e dos impostos aplicados ao preço de fábrica. Faça um programa que receba o preço de fábrica de um veículo, o percentual de lucro do distribuidor e o percentual de impostos, calcule e mostre:
# * o valor correspondente ao lucro do distribuidor;
# * o valor correspondente aos impostos;
# * o preço final do veículo.
#         LEIA preco_fabrica
#         LEIA percentual_lucro_distribuidor
#         LEIA percentual_imposto
#         lucro_distribuidor = preco_fabrica * percentual_lucro_distribuidor / 100
#         valor_imposto = preco_fabrica * percentual_imposto / 100
#         preco_final = preco_fabrica + lucro_distribuidor + valor_imposto
#         ESCREVA lucro_distribuidor
#         ESCREVA valor_imposto
#         ESCREVA preco_final

# %%
preco_de_fabrica = float(input('insira o preço de fabrica '))
percentual = float(input('insira o percentual '))
impostos = float(input('insira o imposto '))
lucro = preco_de_fabrica * (percentual /100)
imposto = preco_de_fabrica * impostos / 100
preco_final = preco_de_fabrica + lucro + imposto
print('o lucro do distribuidor é', lucro)
print('o valor dos impostos é', imposto)
print('o preço final é', preco_final)
# Out:
# insira o preço de fabrica 5000
# insira o percentual 50
# insira o imposto 20
# o lucro do distribuidor é 2500.0
# o valor dos impostos é 1000.0
# o preço final é 8500.0

# %% [markdown]
# ### 16. Faça um programa que receba o número de horas trabalhadas e o valor do salário mínimo, calcule e mostre o salário a receber, seguindo estas regras:
# * a hora trabalhada vale a metade do salário mínimo.
# * o salário bruto equivale ao número de horas trabalhadas multiplicado pelo valor da hora trabalhada.
# * o imposto equivale a 3% do salário bruto.
# * o salário a receber equivale ao salário bruto menos o imposto.
#       LEIA qtde_horas_trabalhadas
#       LEIA valor_salario_minimo
#       valor_hora_trabalhada = valor_salario_minimo / 2
#       valor_salario_bruto = valor_hora_trabalhada * qtde_horas_trabalhadas
#       imposto = valor_salario_bruto * 3 / 100
#       valor_salario_liquido =  valor_salario_bruto - imposto
#       ESCREVA valor_salario_liquido

# %%
qtde_horas_trabalhadas = float(input('insira a qtde de horas '))
salario_minimo = float(input('insira o salario minimo'))
valor_da_hr_trab = salario_minimo / 2
salario_bruto = valor_da_hr_trab * qtde_horas_trabalhadas
imposto = salario_bruto * 3 / 100
salario_a_receber = salario_bruto - imposto
print('o salario a receber é', salario_a_receber)
# Out:
# insira a qtde de horas 8
# insira o salario minimo1200
# o salario a receber é 4656.0

# %% [markdown]
# ### 17. Um trabalhador recebeu seu salário e o depositou em sua conta bancária. Esse trabalhador emitiu dois cheques e agora deseja saber seu saldo atual. O banco criou uma taxa para a operação bancária de retirada que tem que pagar um imposto de 0.38% e o saldo inicial da conta está zerado.
#
#       LEIA salario
#       LEIA valor_cheque1
#       LEIA valor_cheque2
#       imposto_cheque1 = valor_cheque1 * 0.38 / 100
#       saque1 = valor_cheque1 + imposto_cheque1
#       imposto_cheque2 = valor_cheque2 * 0.38 / 100
#       saque2 = valor_cheque2 + imposto_cheque2
#       saldo = salario - saque1 - saque2
#       ESCREVA saldo

# %%
salario = float(input('insira o saalrio '))
valor_do_cheque1 = float(input('insira o valor do cheque 1 '))
valor_do_cheque2 = float(input('insira o valor do cheque 2 '))
imposto_cheque1 = valor_do_cheque1 * 0.38 /100
saque1 = valor_do_cheque1 + imposto_cheque1
imposto_cheque2 = valor_do_cheque2 * 0.38 / 100
saque2 = valor_do_cheque2 + imposto_cheque2
saldo = salario - saque1 - saque2
print(f'o saldo atual é de {saldo:.2f}')
# Out:
# insira o saalrio 4885
# insira o valor do cheque 1 475
# insira o valor do cheque 2 231
# o saldo atual é de 4176.32

# %% [markdown]
# ### 18. Faça um programa que receba a medida do ângulo (em graus) formado por uma escada apoiada no chão e encostada na parede e a altura da parede onde está a ponta da escada. Calcule e mostre a medida dessa escada. Observação: as funções trigonométricas implementadas nas linguagens de programação trabalham com medidas de ângulos em radianos.
#       LEIA angulo
#       LEIA altura
#       import math # carrega a biblioteca matemática
#       radiano = angulo * math.pi / 180
#       escada = altura / math.sin(radiano)
#       ESCREVA escada
# **Observação**: Para usar seno em Python, deve-se usar esta linha de código **import math** e esta, no cálculo, **math.sin(numero)**
#
# **import math**
#
# escada = altura / **math.sin**(numero)

# %%
import math
angulo = float(input('insira o angulo '))
altura_parede = float(input('insira a altura '))
radiano = angulo * math.pi / 180
escada = altura_parede / math.sin(radiano)
print(f'a medida da escada é {escada:.2f}')
# Out:
# insira o angulo 45
# insira a altura 3
# a medida da escada é 4.24

# %% [markdown]
# ###19. Sabe-se que o quilowatt de energia custa um quinto do salário mínimo. Faça um programa que receba o valor do salário mínimo e a quantidade de quilowatts consumida por uma residência. Calcule e mostre:
#
#
# * o valor de cada quilowatt;
# * o valor a ser pago por essa residência;
# * o valor a ser pago com desconto de 15%.
#       LEIA valor_salario
#       LEIA qtde_quilowatt
#       valor_quilowatt = valor_salario / 5
#       valor_em_reais = valor_quilowatt * qtde_quilowatt
#       valor_descontado = valor_em_reais * 15 / 100
#       valor_com_desconto =  valor_em_reais − valor_descontado
#       ESCREVA valor_quilowatt
#       ESCREVA valor_em_reais
#       ESCREVA valor_com_desconto

# %%
salario_min = int(input('insira o salario minimo '))
qtde_quilowatt = int(input('insira a qtde consumida de kwtt '))
valor_do_kwtt = salario_min / 5
valor_a_ser_pago = valor_do_kwtt * qtde_quilowatt
valor_descontado = valor_a_ser_pago * 15 / 100
valor_com_desconto = valor_a_ser_pago - valor_descontado
print('o valor de cada kwtt é', valor_do_kwtt)
print('o valor a ser pago é', valor_a_ser_pago)
print('o valor com desconto é de', valor_com_desconto)
# Out:
# insira o salario minimo 1200
# insira a qtde consumida de kwtt 2
# o valor de cada kwtt é 240.0
# o valor a ser pago é 480.0
# o valor com desconto é de 408.0

# %% [markdown]
# ### 20. Faça um programa que receba um número real, encontre e mostre:
#
# * a parte inteira desse número;
# * a parte fracionária desse número;
# * o arredondamento desse número.
#
#       LEIA numero
#       parte_inteira = numero // 1
#       parte_fracionaria = numero - parte_inteira
#       numero_arredondado = round (numero)
#       ESCREVA parte_inteira
#       ESCREVA parte_fracionaria
#       ESCREVA numero_arredondado
#
# **Observação**: Para arredondar um número em Python, usa-se a função **round(numero)**, onde se o número real/float estiver em igual distância entre o inteiro de cima e o inteiro de baixo, esta função arredonda para o número mais próximo.

# %%
numero = float(input('insira o numero '))
inteiro = numero // 1 
fracionado = numero - inteiro
arredondado = round (numero)
print('a parte inteira do numero é', inteiro)
print('a parte fracionado do numero é', fracionado)
print('a parte arredondado do numero é', arredondado)
# Out:
# insira o numero 10.55
# a parte inteira do numero é 10.0
# a parte fracionado do numero é 0.5500000000000007
# a parte arredondado do numero é 11

# %% [markdown]
# ### 21. Faça um programa que receba uma hora formada por hora e minutos (um número real), calcule e mostre a hora digitada apenas em minutos. Lembre-se de que:
# * para quatro e meia, deve-se digitar 4.30;
# * os minutos vão de 0 a 59.
#       LEIA hora
#       h = pegar a parte inteira da variável hora
#       minutos = hora − h
#       conversao = (h * 60) + (minutos * 100)
#       ESCREVA conversao

# %%
hora = float(input('informe a hora' ))
h = hora // 1 
minutos = hora - h
conversao = (h * 60) + (minutos * 100)
print('minutos', conversao)
# Out:
# informe a hora2.08
# minutos 128.0

# %% [markdown]
# ### 22. Faça um programa que receba o custo de um espetáculo teatral e o preço do convite desse espetáculo. Esse programa deverá calcular e mostrar a quantidade de convites que devem ser vendidos para que, pelo menos, o custo do espetáculo seja alcançado.

# %%
custo = float(input('insira o valor '))
convite = float(input('insira o valor do convite'))
qtde_de_convites = custo / convite
print('a quantidade de convites necessarios para cobrir o custo é de', qtde_de_convites)
# Out:
# insira o valor 10000
# insira o valor do convite50
# a quantidade de convites necessarios para cobrir o custo é de 200.0
