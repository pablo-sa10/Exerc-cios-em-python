# %% [markdown]
# #**EXERCÍCIOS SOBRE VETOR DO 1 AO 20**

# %% [markdown]
# ### 1. Faça um programa que calcule e apresente a média de idades de uma sala de 35 alunos.​​

# %%
idade = [] 
soma_idade = 0
for i in range(3):
    idade.append(int(input('Informe a '+ str(i+1) +'ª idade: ')))
    soma_idade = soma_idade + idade[i]
media = soma_idade / len(idade)
print(f'A média é {media:.2f} anos.')
# Out:
# Informe a 4ª idade: 34
# Informe a 4ª idade: 67
# Informe a 4ª idade: 21
# A média é 40.67 anos.

# %% [markdown]
# ### 2. Faça um programa que calcule e apresente a média de alturas de uma sala de 35 alunos. Informe também quantos alunos **e** quais (índice/posição) são os que possuem idade superior a 25 anos.​ Use dois vetores, um para altura e outro para idade. Não use nenhuma função pronta da linguagem Python.

# %%
soma = 0
altura = []
idade = []
for i in range(3):
    altura.append(float(input('digite a altura: ')))
    idade.append(float(input('digite a idade: ')))
    soma = soma + altura[i]
media = soma / len(altura)

qtd_pessoas = 0
for i in range(len(idade)):
    if idade[i] > 25:
        qtd_pessoas += 1
        print('o aluno nº',i,'possui',idade[i],'anos')
print('quantidade de alunos com mais de 25 anos: ',qtd_pessoas)
print(altura)
print(idade)
# Out:
# digite a altura: 180
# digite a idade: 19
# digite a altura: 190
# digite a idade: 30
# digite a altura: 165
# digite a idade: 33
# o aluno nº 1 possui 30.0 anos
# o aluno nº 2 possui 33.0 anos
# quantidade de alunos com mais de 25 anos:  2
# [180.0, 190.0, 165.0]
# [19.0, 30.0, 33.0]

# %% [markdown]
# ### 3. Faça um programa que carregue um vetor de dez elementos que contenha o nome de pessoas e outro que contenha o peso, encontre qual a pessoa mais gorda e mais magra e apresente o nome o peso das mesmas.​ Use dois vetores, um para peso e outro para nome. Não use nenhuma função pronta da linguagem Python.

# %%
nome = []
peso = []
for i in range(3):
    nome.append(input('digite o nome da pessoa '))
    peso.append(float(input('digite o peso da pessoa ')))
print(nome)
print(peso)
for i in range(len(nome)):
    if i == 0:
        fat = peso[i]
        fit = peso[i]
        nome_gordo = nome[i]
        nome_magro = nome[i]

    if peso[i] >= fat:
        fat = peso[i]
        nome_gordo = nome[i]

    elif peso[i] < fit:
        fit = peso[i]
        nome_magro = nome[i]

print(nome_gordo,'é a pessoa mais gorda, com',fat,'kilos')
print(nome_magro,'é a pessoa mais magra, com',fit,'kilos')
# Out:
# digite o nome da pessoa pablo
# digite o peso da pessoa 70
# digite o nome da pessoa lucas
# digite o peso da pessoa 77
# digite o nome da pessoa matheus
# digite o peso da pessoa 80
# ['pablo', 'lucas', 'matheus']
# [70.0, 77.0, 80.0]
# matheus é a pessoa mais gorda, com 80.0 kilos
# pablo é a pessoa mais magra, com 70.0 kilos

# %% [markdown]
# ### 4. Faça um programa que carregue um vetor com a média de dez alunos, calcule e mostre a MÉDIA DA SALA e quantos alunos estão acima e abaixo da média da sala.

# %%
# Digite seu código aqui
soma = 0
media = []
acima = 0
abaixo = 0
for i in range(4):
    media.append(int(input('digite a media do aluno: ')))
    soma = soma + media[i]
media_sala = soma / len(media)
print('a media da sala é:',media_sala)
for i in range (len(media)):
    if media[i] >= media_sala:
        acima +=1
    elif media[i] < media_sala:
        abaixo +=1
print(acima,'estao acima da media')
print(abaixo,'estao abaixo da media')
# Out:
# digite a media do aluno: 10
# digite a media do aluno: 9
# digite a media do aluno: 8
# digite a media do aluno: 5
# a media da sala é: 8.0
# 3 estao acima da media
# 1 estao abaixo da media

# %% [markdown]
# ### 5. Faça um programa que carregue um vetor de oito elementos numéricos inteiros, calcule e mostre os números pares e suas respectivas índices/posições. Não use nenhuma função pronta da linguagem Python.

# %%
# Digite seu código aqui.
numero = []
for i in range(1,9):
    numero.append(int(input('digite um numero inteiro: ')))
print('os numeros inteiros são:',numero)

for i in range(len(numero)):
    if numero[i] % 2 == 0:
        print('o numero:',numero[i],'na posição',i,'é par')
# Out:
# digite um numero inteiro: 18
# digite um numero inteiro: 99
# digite um numero inteiro: 22
# digite um numero inteiro: 45
# digite um numero inteiro: 1
# digite um numero inteiro: 35
# digite um numero inteiro: -64
# digite um numero inteiro: 100
# os numeros inteiros são: [18, 99, 22, 45, 1, 35, -64, 100]
# o numero: 18 na posição 0 é par
# o numero: 22 na posição 2 é par
# o numero: -64 na posição 6 é par
# o numero: 100 na posição 7 é par

# %% [markdown]
# ### 6. Faça um programa que carregue um vetor com dez nomes e faça uma verificação se um determinado nome esta nesse vetor. Não use nenhuma função pronta da linguagem Python.

# %%
# Digite seu código aqui
nome = []
for i in range(4):
    nome.append(input('digite o nome da pessoa: '))
print(nome)
nome_pesquisa = input('qual nome deseja encontrar? ')
if nome_pesquisa in nome:
    print('nome encontrado')
else:
    print('nome não encontrado')
# Out:
# digite o nome da pessoa: pablo
# digite o nome da pessoa: lucas
# digite o nome da pessoa: matheus
# digite o nome da pessoa: pedro
# ['pablo', 'lucas', 'matheus', 'pedro']
# qual nome deseja encontrar? edy
# nome não encontrado

# %% [markdown]
# ### 7. Faça um algoritmo que calcule e apresente a média de alturas superior a 1,80 de 10 alunos. Informe também quantos e quais (índice/posição) são os alunos. Não use nenhuma função pronta da linguagem Python.

# %%
# Digite seu código aqui.
altura = []
soma_altura = 0
soma_alunos = 0
for i in range(10):
    altura.append(float(input('digite a altura: ')))
    if altura[i] > 180:
        soma_altura = soma_altura + altura[i]
        soma_alunos += 1
        print('o aluno da posição',i,'possui mais de 1,80')
media_altura = soma_altura / soma_alunos
print()
print(f'a media das alturas dos alunos com mais de 1,80 é: {media_altura:.2f}')
print()
print(soma_alunos,'alunos tem mais de 1,80')
# Out:
# digite a altura: 182
# o aluno da posição 0 possui mais de 1,80
# digite a altura: 195
# o aluno da posição 1 possui mais de 1,80
# digite a altura: 172
# digite a altura: 165
# digite a altura: 198
# o aluno da posição 4 possui mais de 1,80
# digite a altura: 200
# o aluno da posição 5 possui mais de 1,80
# digite a altura: 155
# digite a altura: 166
# digite a altura: 177
# digite a altura: 180
#
# a media das alturas dos alunos com mais de 1,80 é: 193.75
#
# 4 alunos tem mais de 1,80

# %% [markdown]
# ### 8. Criar um algoritmo que a partir de um vetor de 10 elementos inteiros, crie outros dois vetores que receberão os elementos positivos e negativos e ao final apresente-os. Não use nenhuma função pronta da linguagem Python.

# %%
# Digite seu código aqui
numero = []
numero_pos = []
numero_neg = []
for i in range(10):
    numero.append(int(input('digite um numero inteiro: ')))
print('\nos numeros inteiros sao:',numero,'\n')
for i in range(len(numero)):
    if numero[i] > 0:
        numero_pos.append(numero[i])
    else:
        numero_neg.append(numero[i])
print(f'os numeros positivos são {numero_pos}')
print(f'os numeros negativos são {numero_neg}')
# Out:
# digite um numero inteiro: 1
# digite um numero inteiro: 2
# digite um numero inteiro: -3
# digite um numero inteiro: 4
# digite um numero inteiro: 5
# digite um numero inteiro: -6
# digite um numero inteiro: -7
# digite um numero inteiro: -8
# digite um numero inteiro: 1000
# digite um numero inteiro: -1
#
# os numeros inteiros sao: [1, 2, -3, 4, 5, -6, -7, -8, 1000, -1]
#
# os numeros positivos são [1, 2, 4, 5, 1000]
# os numeros negativos são [-3, -6, -7, -8, -1]

# %% [markdown]
# ### 9. Criar um algoritmo que leia dados para um vetor de 100 elementos inteiros, imprimir o maior, o menor, o percentual de números pares e a média dos elementos do vetor. Obs.: percentual = quantidade contada * 100 / quantidade total. Não use nenhuma função pronta da linguagem Python.

# %%
# Digite seu código aqui.
vetor = []
soma_pares = 0
soma_elementos = 0
for i in range(100):
    vetor.append(int(input('digite um numero inteiro: ')))
    if i == 0:
        maior = vetor[i]
        menor = vetor[i]
    if vetor[i] >= maior:
        maior = vetor[i]
    elif vetor[i] <= menor:
        menor= vetor[i]
print()
print('o maior numero é:', maior)
print('o menor numero é:', menor)
print()

for i in range(len(vetor)):
    if vetor[i] % 2 == 0:
        soma_pares += 1
        percentual = soma_pares * 100 / len(vetor)
print(f'o percentual de numeros pares é de {percentual}%')
print()

for i in range(len(vetor)):
    soma_elementos = soma_elementos + vetor[i]
media =  soma_elementos / len(vetor)
print(f'a media dos elementoes é {media}')
# Out:
# digite um numero inteiro: 1
# digite um numero inteiro: 2
# digite um numero inteiro: 3
# digite um numero inteiro: 4
# digite um numero inteiro: 5
#
# o maior numero é: 5
# o menor numero é: 1
#
# o percentual de numeros pares é de 40.0%
#
# a media dos elementoes é 3.0

# %% [markdown]
# ### 10. Faça um programa que:
#
# * preencha um vetor com seis elementos numéricos inteiros.
#
# **Calcule e mostre:**
#
# * todos os números pares;
# * a quantidade de números pares;
# * todos os números ímpares;
# * a quantidade de números ímpares

# %%
# Digite seu código aqui.
numero = []
pares = []
impares = []
soma_par = 0
soma_impar = 0
for i in range(6):
    numero.append(int(input('digite um numero inteiro: ')))
print(f'\nos numeros inteiros sao:{numero}\n')
for i in range(len(numero)):
    if numero[i] % 2 == 0:
        soma_par += 1
        pares.append(numero[i])
    else:
        soma_impar += 1
        impares.append(numero[i])
print(f'são {soma_par} numeros pares')
print(f'os numeros pares são: {pares}\n')
print(f'são {soma_impar} numeros impares')
print(f'os numeros impares são: {impares}\n')
# Out:
# digite um numero inteiro: 1
# digite um numero inteiro: 2
# digite um numero inteiro: 3
# digite um numero inteiro: 4
# digite um numero inteiro: 5
# digite um numero inteiro: 6
#
# os numeros inteiros sao:[1, 2, 3, 4, 5, 6]
#
# são 3 numeros pares
# os numeros pares são: [2, 4, 6]
#
# são 3 numeros impares
# os numeros impares são: [1, 3, 5]

# %% [markdown]
# ### 11. Faça um programa que:
#
# * preencha um vetor com sete números inteiros
#
# **Calcule e mostre:**
#
# * os números múltiplos de 2;
# * os números múltiplos de 3;
# * os números múltiplos de 2 e de 3.

# %%
# Digite seu código aqui.
numero = []
multiplo_2 = []
multiplo_3 = []
multiplo_2_3 = []
for i in range(5):
    numero.append(int(input('digite um numero inteiro: ')))
print(f'\nos numeros inteiros sao:{numero}\n')
for i in range(len(numero)):
    if numero[i] % 2 == 0:
        multiplo_2.append(numero[i])
    if numero[i] % 3 == 0:
        multiplo_3.append(numero[i])
    if numero[i] % 3 == 0 and numero[i] % 2 == 0:
        multiplo_2_3.append(numero[i])
print(f'os multiplos de 2 são: {multiplo_2}')
print(f'os multiplos de 3 são: {multiplo_3}')
print(f'os multiplos de 2 e 3 são: {multiplo_2_3}')
# Out:
# digite um numero inteiro: 1
# digite um numero inteiro: 2
# digite um numero inteiro: 3
# digite um numero inteiro: 4
# digite um numero inteiro: 6
#
# os numeros inteiros sao:[1, 2, 3, 4, 6]
#
# os multiplos de 2 são: [2, 4, 6]
# os multiplos de 3 são: [3, 6]
# os multiplos de 2 e 3 são: [6]

# %% [markdown]
# ### 12. Faça um programa que:
#
# * preencha um vetor com quinze elementos inteiros
# * verifique a existência de elementos iguais a 30, mostrando os índices/posições em que apareceram.

# %%
# Digite seu código aqui.
numero = []
for i in range(4):
    numero.append(int(input('digite um numero inteiro: ')))
print(f'\nos numeros inteiros sao:{numero}\n')
numero_30 = 30
for i in range(len(numero)):
    if numero_30 == numero[i]:
        print(f'o numero 30 foi encontrado, e está na posição {i}')
    else:
        print('numero nao encontrado')
# Out:
# digite um numero inteiro: 30
# digite um numero inteiro: 1
# digite um numero inteiro: 2
# digite um numero inteiro: 3
#
# os numeros inteiros sao:[30, 1, 2, 3]
#
# o numero 30 foi encontrado, e está na posição 0
# numero nao encontrado
# numero nao encontrado
# numero nao encontrado

# %% [markdown]
# ### 13. Faça um programa que:
#
# * preencha um vetor com dez números reais
#
# **Calcule e mostre:**
#
# * a quantidade de números negativos
# * a soma dos números positivos desse *vetor*
# * não use nenhuma função pronta da linguagem Python

# %%
# Digite seu código aqui.
numero = []
negativo = []
soma = []
soma2 = 0
neg = 0
for i in range(4):
    numero.append(float(input('digite um numero real: ')))
print(f'\nos numeros reais sao:{numero}\n')

for i in range(len(numero)):
    if numero[i] < 0:
        neg += 1
        negativo.append(numero[i])
    else:
        soma2 = soma2 + numero[i]
        soma.append(numero[i])

print(f'os numeros negativos são: {negativo}')
print(f'a quantidade de numeros negativos é: {neg}\n')
print(f'os numeros positivos são: {soma}')
print(f'a soma dos numeros positivos é: {soma2}')
# Out:
# digite um numero real: 1
# digite um numero real: 2
# digite um numero real: -3
# digite um numero real: -4
#
# os numeros reais sao:[1.0, 2.0, -3.0, -4.0]
#
# os numeros negativos são: [-3.0, -4.0]
# a quantidade de numeros negativos é: 2
#
# os numeros positivos são: [1.0, 2.0]
# a soma dos numeros positivos é: 3.0

# %% [markdown]
# ### 14. Faça um programa que:
#
# * receba dez números inteiros e armazene-os em um vetor
# * classifique os números em dois vetores, um com números pares e o outra com os ímpares
# * não use nenhuma função pronta da linguagem Python

# %%
# Digite seu código aqui.
numero = []
par = []
impar = []
for i in range(5):
    numero.append(int(input('digite um numero inteiro: ')))
print(f'\nos numeros são: {numero}\n')
for i in range(len(numero)):
    if numero[i] % 2 == 0:
       par.append(numero[i]) 
    else:
        impar.append(numero[i])

print(f'os numeros pares são: {par}\n')
print(f'os numeros impares são: {impar}')
# Out:
# digite um numero inteiro: 1
# digite um numero inteiro: 2
# digite um numero inteiro: 3
# digite um numero inteiro: 4
# digite um numero inteiro: 5
#
# os numeros são: [1, 2, 3, 4, 5]
#
# os numeros pares são: [2, 4]
#
# os numeros impares são: [1, 3, 5]

# %% [markdown]
# ### 15. Faça um programa que:
#
# * preencha um vetor com quinze números
#
# **Determine e mostre:**
#
# * o maior número e a posição por ele ocupada no vetor
# * o menor número e a posição por ele ocupada no vetor
# * Não use nenhuma função pronta da linguagem Python

# %%
# Digite seu código aqui.
numero = []
for i in range(4):
    numero.append(int(input('digite um numero inteiro ')))
print(f'os numeros inteiros são: {numero}\n')
for i in range(len(numero)):
    if i == 0:
        maior = numero[i]
        menor = numero[i]
    if numero[i] >= maior:
        maior = numero[i]
    elif numero[i] <= menor:
        menor = numero[i]
print(f'o maior numero é: {maior} e está na posição {i}\n')
print(f'o menor numero é: {menor} e esta na posição {i}\n')
# Out:
# digite um numero inteiro 1
# digite um numero inteiro 2
# digite um numero inteiro 3
# digite um numero inteiro 4
# os numeros inteiros são: [1, 2, 3, 4]
#
# o maior numero é: 4 e está na posição 3
#
# o menor numero é: 1 e esta na posição 3

# %% [markdown]
# ### 16. Faça um programa que:
#
# * preencha dois vetores com de dez numeros cada
# * preencha um terceiro vetor com os números dos dois vetores anteriores ordenados em ordem crescente

# %%
# Digite seu código aqui.
vet1 = []
vet2 = []
vet3 = []
for i in range(4):
    vet1.append(int(input('.....digite um numero p/ o vetor 1: ')))
for i in range(len(vet1)):
    vet2.append(int(input('.....digite um numero p/ o vetor 2: ')))
print(f'\nos numeros do primeiro vetor são: {vet1}')
print(f'os numeros do segundo vetor são: {vet2}')

for i in range(len(vet2)):
    vet3.append(vet1[i])
    vet3.append(vet2[i])
    vet3.sort()
print(f'\n{vet3}')
# Out:
# .....digite um numero p/ o vetor 1: 9
# .....digite um numero p/ o vetor 1: 8
# .....digite um numero p/ o vetor 1: 7
# .....digite um numero p/ o vetor 1: 6
# .....digite um numero p/ o vetor 2: 5
# .....digite um numero p/ o vetor 2: 4
# .....digite um numero p/ o vetor 2: 3
# .....digite um numero p/ o vetor 2: 2
#
# os numeros do primeiro vetor são: [9, 8, 7, 6]
# os numeros do segundo vetor são: [5, 4, 3, 2]
#
# [2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# ### 17. Faça um programa que:
#
# * carregue dois vetores com 10 números cada
# * faça a multiplicação dos números na mesma posição
# * o resultado deverá ser adicionada em um terceiro vetor
# * não use nenhuma função pronta da linguagem Python

# %%
a = []
b = []
c = []
for i in range(4):
    a.append(int(input('digite o valor do vetor a ')))
    b.append(int(input('digite o valor do vetor b ')))

for i in range(len(a)):
    c.append(a[i] * b[i])

print(f'\n{a}')
print(f'{b}')
print(f'\na multiplicação: {c}')
# Out:
# digite o valor do vetor a 1
# digite o valor do vetor b 1
# digite o valor do vetor a 2
# digite o valor do vetor b 2
# digite o valor do vetor a 3
# digite o valor do vetor b 3
# digite o valor do vetor a 4
# digite o valor do vetor b 4
#
# [1, 2, 3, 4]
# [1, 2, 3, 4]
#
# a multiplicação: [1, 4, 9, 16]

# %% [markdown]
# ### 18. Faça um programa que:
#
# * leia um vetor de 10 números inteiros
# * exiba na tela os números positivos e seus respectivos índices.
# * não use nenhuma função pronta da linguagem Python

# %%
# Digite seu código aqui.
numero = []
positivos = []
for i in range(6):
    numero.append(int(input('digite um numero inteiro ')))
print(f'\nos numeros inteiros são: {numero}\n')

for i in range(len(numero)):
    if numero[i] > 0:
        print(f'o numero {numero[i]} é positivo e está na posição {i}')
        positivos.append(numero[i])
print(f'\nos numeros postivos são: {positivos}')
# Out:
# digite um numero inteiro 1
# digite um numero inteiro -2
# digite um numero inteiro 3
# digite um numero inteiro -5
# digite um numero inteiro 7
# digite um numero inteiro 65
#
# os numeros inteiros são: [1, -2, 3, -5, 7, 65]
#
# o numero 1 é positivo e está na posição 0
# o numero 3 é positivo e está na posição 2
# o numero 7 é positivo e está na posição 4
# o numero 65 é positivo e está na posição 5
#
# os numeros postivos são: [1, 3, 7, 65]

# %% [markdown]
# ### 19. Faça um programa que:
#
# * insira dez números inteiros em um vetor
# * crie um segundo vetor, substituindo os números multiplos de 3 por "999""
# * exiba os dois vetores
# * não use nenhuma função pronta da linguagem Python

# %%
# Digite seu código aqui.
numero = []
vet2 = []
mult = 999
for i in range(6):
    numero.append(int(input('digite um numero inteiro: ')))
print(f'\nos numeros inteiros sao:{numero}\n')

for i in range(len(numero)):
    vet2.append(numero[i])
    if numero[i] % 3 == 0:
        vet2[i] = mult
print(vet2)
# Out:
# digite um numero inteiro: 2
# digite um numero inteiro: 3
# digite um numero inteiro: 5
# digite um numero inteiro: 6
# digite um numero inteiro: 7
# digite um numero inteiro: 9
#
# os numeros inteiros sao:[2, 3, 5, 6, 7, 9]
#
# [2, 999, 5, 999, 7, 999]

# %% [markdown]
# ### 20. Faça um programa que:
#
# * leia dois vetores (A e B) com cinco posições para números inteiros.
# * o programa deve, então, subtrair o primeiro elemento de A do último de B, armazenando o resultado num terceiro vetor, subtrair o segundo elemento de A do penúltimo de B, armazenando o resultado num terceiro vetor e assim por diante.
# * ao final, mostre o resultado do terceiro vetor
# * não use nenhuma função pronta da linguagem Python

# %%
a = []
b = []
c = []
for i in range(5):
    a.append(int(input('digite o valor do vetor a ')))
    b.append(int(input('digite o valor do vetor b ')))
posicao = len(a) - 1
for i in range(len(a)):
    c.append(a[i] - b[posicao])
    posicao = posicao - 1

print(a)
print(b)
print(c)
# Out:
# digite o valor do vetor a 89
# digite o valor do vetor b 68
# digite o valor do vetor a 41
# digite o valor do vetor b 32
# digite o valor do vetor a 64
# digite o valor do vetor b 79
# digite o valor do vetor a 55
# digite o valor do vetor b 76
# digite o valor do vetor a 93
# digite o valor do vetor b 38
# [89, 41, 64, 55, 93]
# [68, 32, 79, 76, 38]
# [51, -35, -15, 23, 25]

# %% [markdown]
# #  **EXERCÍCIOS OPCIONAIS, PARA ESTUDO - EXTRA**

# %% [markdown]
# ###21. Faça um programa que:
#
# * preencha um vetor de cinco números e mostre a saída a seguir:
# * imprima a seguinte saída, exemplo (soma_dos_numeros e o sinal de adição) 8 + 2 + 1 + 3 + 0 = 14
# * não use nenhuma função pronta da linguagem Python

# %%
# Digite seu código aqui.

# %% [markdown]
# ### 22. Faça um programa que:
# * leia um vetor com quinze posições para números inteiros.
# * depois da leitura, divida todos os seus elementos pelo maior valor do vetor.
# * Mostre o vetor após os cálculos.
# * não use nenhuma função pronta da linguagem Python

# %%
# Digite seu código aqui.

# %% [markdown]
# ### 23. Um vetor é palíndromo se ele não se alterar quando o mesmo for invertido. Escreva um programa que verifique se um vetor é palíndromo, fazendo comparação de índice/posição por índice/posição do vetor original (vo) com o vetor invertido (vi). Não use nenhuma função pronta da linguagem Python. A tamanho do vetor pode ser da sua escolha.
# Exemplo:
# vetor original    vo = {1, 3, 5, 2, 2, 5, 3, 1}
# vetor invertido é vi = {1, 3, 5, 2, 2, 5, 3, 1}
# O vetor invertido **é palíndromo**, pois ele invertido é igual ao original
#
# vetor original    vo = {9, 7, 5, 2, 4, 5, 3, 6}
# vetor invertido é vi = {6, 3, 5, 4, 2, 5, 7, 9}
# O vetor invertido **não é palíndromo**, pois ele invertido é igual ao original

# %%
# Digite seu código aqui.
