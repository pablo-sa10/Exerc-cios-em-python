# %% [markdown]
# ### 1. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método que leia um número e o multiplique por 2 retornando o resultado e o apresente.

# %%
# Digite aqui seu código
def multiplicar():
    numero = int(input('digite um numero: '))
    resultado = numero * 2
    return resultado

def main():
    print('entrei na main')
    r = multiplicar()
    print('resultado da multiplicação:',r)
    if r > 10:
        print('alguma coisa')
    else:
        w = r + 200

main()
# Out:
# entrei na main
# digite um numero: 5
# resultado da multiplicação: 10

# %% [markdown]
# ### 2. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método para subtrair dois números, retornar o resultado e o apresentando.

# %%
# Digite aqui seu código
def subtrair():
    a = int(input('digite um numero: '))
    b = int(input('digite outro numero: '))
    resultado = a - b
    return resultado

def main():
    r = subtrair()
    print('resultado da subtração:',r)

main()
# Out:
# digite um numero: 3
# digite outro numero: 5
# resultado da subtração: -2

# %% [markdown]
# ### 3. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método que leia a base e a altura de um triângulo e retorne/apresente sua área A = (base x altura)/2.

# %%
# Digite aqui seu código
def triangulo():
    b = int(input('digite um numero: '))
    h = int(input('digite outro numero: '))
    a =(b * h) / 2
    return a

def main():
    x = triangulo()
    print('resultado da area:',x)

main()
# Out:
# digite um numero: 3
# digite outro numero: 4
# resultado da area: 6.0

# %% [markdown]
# ### 4. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método que leia o lado de um quadrado e retorne sua área, area = lado².

# %%
# Digite aqui seu código
def quadrado():
    lado = int(input('digite o valor do lado: '))
    area = lado**2
    return area

def main():
    x = quadrado()
    print('resultado da area:',x)

main()
# Out:
# digite o valor do lado: 6
# resultado da area: 36

# %% [markdown]
# ###5. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método  que verifique se um número é par, retorne mostrando a str/string ‘É par’ ou se ‘É ímpar’.

# %%
# Digite aqui seu código
def n():
    valor = int(input('digite um valor: '))
    if valor % 2 == 0:
        return 'é par'
    else:
        return 'é ímpar'

def main():
    x = n()
    print(x)

main()
# Out:
# digite um valor: 4
# é par

# %% [markdown]
# ###6. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método  que verifique se um número é par, retorne/mostre o valor bool **True** para par e **False** para ímpar.

# %%
# Digite aqui seu código
def n():
    valor = int(input('digite um valor: '))
    if valor % 2 == 0:
        return True
    else:
        return False

def main():
    x = n()
    print(x)

main()
# Out:
# digite um valor: 5
# False

# %% [markdown]
# ### 7. (Função com retorno sem parâmetro) Faça uma função/método que leia e armazene 5 elementos inteiros no vetor A, deverá ser gerado um vetor B, de mesmo tamanho, que armazenará o fatorial de cada elemento de A. Não use função pronta de cálculo de fatorial. Retorne/apresente o vetor B.

# %%
# Exemplo:
# A = [5  ,4 ,3,2,1]
# B = [120,24,6,2,1]
def a():
    A = []
    for i in range(4):
        A.append(int(input(f'digite o {i+1}º numero: ')))

    B = []
    for elemento in A:
        fat = 1
        for i in range(1, elemento+1):
            fat *= i
        B.append(fat)
    
    return B

def main():
    resultado = a()
    print(resultado)

main()
# Out:
# digite o 1º numero: 4
# digite o 2º numero: 6
# digite o 3º numero: 3
# digite o 4º numero: 9
# [24, 720, 6, 362880]

# %% [markdown]
# ### 8. (Função com retorno sem parâmetro) Faça uma função/método retorne um vetor com os três primeiros números perfeitos. Sabe-se que um número é perfeito quando é igual a soma de seus divisores (exceto ele mesmo).
# Exemplo: os divisores de 6 são 1, 2 e 3, e 1 + 2 + 3 = 6, logo 6 é perfeito. Não use função pronta.
#
# 1º número perfeito: 6
#
# 2º número perfeito: 28
#
# 3º número perfeito: 496

# %%
# número 1 não é perfeito
# ...
# número 4 não é perfeito, exemplo: 4 % 1 == 0, 4 % 2 == 0, 4 % 3 != 0, a soma 
# resulta em 2
# ...
# número 6 é perfeito  6 % 1 == 0, 6 % 2 == 0, 6 % 3 == 0, 6 % 4 != 0, 6 % 5 != 0
# quando é perfeito a soma de seus divisores da o mesmo valor de número que é 6

def vetor():
    perfeito = []
    num = 2

    while len(perfeito) < 3:
        soma_divisor = 1
        for i in range(2, num):
            if num % i == 0: 
                soma_divisor += i
        if soma_divisor == num:
            perfeito.append(num)  
        num += 1

    return perfeito

def main():
    a = vetor()
    print(a)

main()
# Out:
# [6, 28, 496]

# %% [markdown]
# ### 9. (Função com retorno sem parâmetro) Foi realizada uma pesquisa sobre algumas características físicas de cinco habitantes de uma região. Foram coletados os seguintes dados de cada habitante: idade, sexo (M - masculino ou F - feminino), cor dos olhos (A - azuis ou C - castanhos), cor dos cabelos (L - louros, P - pretos ou C - castanhos).
#
# 1.   Faça uma função/método que leia esses dados, armazenando-os em vetores (listas);
# 2.   Faça uma função/método que determine e devolva a função principal a média de idades das pessoas com olhos castanhos e cabelos pretos;
# 3. Faça uma função/método que determine e devolva a função principal a maior idade entre os habitantes;
# 4.  Faça uma função/método que determine e devolva a função principal a quantidade de indivíduos do sexo feminino com idade entre 18 e 35 anos(inclusive) e que tenham olhos azuis e cabelos louros.

# %%
# Declarar os vetores antes de qualquer programação, indica que 
# que estas variáveis serão globais a todo o restante do programa 
# e das funções 
idades = []
sexos = []
olhos = []
cabelos = []

def cadastrar():
    for i in range(2):
        idade = int(input(f"Digite a idade do {i+1}º habitante: "))
        sexo = input(f"Digite o sexo (M ou F) do {i+1}º habitante: ")
        olho = input(f"Digite a cor dos olhos (A ou C) do {i+1}º habitante: ")
        cabelo = input(f"Digite a cor dos cabelos (L, P ou C) do {i+1}º habitante: ")
        idades.append(idade)
        sexos.append(sexo)
        olhos.append(olho)
        cabelos.append(cabelo)
    
    return idades,sexos, olhos, cabelos

def media_idades_castanhos_pretos(idades, olhos, cabelos):
    soma_idades = 0
    qtd_hab = 0

    for i in range(len(idades)):
        if olhos[i] == 'C' and olhos[i] == 'c' and cabelos[i] == 'P' and cabelos[i] == 'p':
            soma_idades += idades[i]
            qtd_hab += 1
    
    if qtd_hab == 0:
        return None
    
    return soma_idades / qtd_hab

def maior_idade(idades):
    maior = idades[0]
    for idade in idades:
        if idade > maior:
            maior = idade
    return maior

def qtd_mulheres_18_35_azuis_louros(idades, sexos, olhos, cabelos):
    qtd = 0
    for i in range(len(idades)):
        if sexos[i] == 'F' and sexos[i] == 'f' and idades[i] >= 18 and idades[i] <= 35 and olhos[i] == 'A' and olhos[i] == 'a' and cabelos[i] == 'L' and cabelos[i] == 'l':
            qtd += 1
    return qtd


def main():
    print('\n',cadastrar())
    print('\na media de idade de pessoas com cabelos castanhos e olhos pretos:', media_idades_castanhos_pretos(idades, olhos, cabelos))
    print('\nmaior idade:',maior_idade(idades))
    qtd = qtd_mulheres_18_35_azuis_louros(idades, sexos, olhos, cabelos)
    print('\nquantidade de mulheres loiras entre 18 e 35 anos:',qtd)

main()
# Out:
# Digite a idade do 1º habitante: 15
# Digite o sexo (M ou F) do 1º habitante: m
# Digite a cor dos olhos (A ou C) do 1º habitante: c
# Digite a cor dos cabelos (L, P ou C) do 1º habitante: p
# Digite a idade do 2º habitante: 20
# Digite o sexo (M ou F) do 2º habitante: f
# Digite a cor dos olhos (A ou C) do 2º habitante: a
# Digite a cor dos cabelos (L, P ou C) do 2º habitante: l
#
#  ([15, 20], ['m', 'f'], ['c', 'a'], ['p', 'l'])
#
# a media de idade de pessoas com cabelos castanhos e olhos pretos: None
#
# maior idade: 20
#
# quantidade de mulheres loiras entre 18 e 35 anos: 0
